# %% [markdown]
# #### 라이브러리 임포트

# %%
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET
import os
import glob

# %% [markdown]
# #### 코랩 구글드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# 공유폴더 -> 정리 -> 바로가기 추가로 공유 폴더 MY DRIVE로 연결
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #### XML데이터를 데이터프레임으로 재구조화

# %%
def make_DB(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()

    # 데이터 추출
    data = {
        'folder': root.find('folder').text if root.find('folder') is not None else None,
        'filename': root.find('filename').text if root.find('filename') is not None else None,
        'width': int(root.find('size/width').text) if root.find('size/width') is not None else None,
        'height': int(root.find('size/height').text) if root.find('size/height') is not None else None,
        'duration': root.find('header/duration').text if root.find('header/duration') is not None else None,
        'fps': int(root.find('header/fps').text) if root.find('header/fps') is not None else None,
        'frames': int(root.find('header/frames').text) if root.find('header/frames') is not None else None,
        'location': root.find('header/location').text if root.find('header/location') is not None else None,
        'season': root.find('header/season').text if root.find('header/season') is not None else None,
        'weather': root.find('header/weather').text if root.find('header/weather') is not None else None,
        'time': root.find('header/time').text if root.find('header/time') is not None else None,
        'population': int(root.find('header/population').text) if root.find('header/population') is not None else None,
        'eventname': root.find('event/eventname').text if root.find('event/eventname') is not None else None,
        'starttime': root.find('event/starttime').text if root.find('event/starttime') is not None else None,
        'action_duration': root.find('event/duration').text if root.find('event/duration') is not None else None
    }

    df1 = pd.DataFrame([data])

    characters = root.find('header/character').text.split(',') if root.find('header/character') is not None else []
    objects_data = [
        {
            'character': characters[i] if i < len(characters) else None,
            'objectname': obj.find('objectname').text if obj.find('objectname') is not None else None,
            'keyframe': int(obj.find('position/keyframe').text) if obj.find('position/keyframe') is not None else None,
            'keypoint_x': float(obj.find('position/keypoint/x').text) if obj.find('position/keypoint/x') is not None else None,
            'keypoint_y': float(obj.find('position/keypoint/y').text) if obj.find('position/keypoint/y') is not None else None,
            'actionname': action.find('actionname').text if action.find('actionname') is not None else None,
            'actionframe_start': int(frame.find('start').text) if frame.find('start') is not None else None,
            'actionframe_end': int(frame.find('end').text) if frame.find('end') is not None else None,
        }
        for i, obj in enumerate(root.findall('object'))
        for action in obj.findall('action')
        for frame in action.findall('frame')
    ]

    df2 = pd.DataFrame(objects_data)
    df2.insert(0, 'file_objectname', df1['filename'][0] +'('+ df2['objectname']+')')

    df1_repeated = pd.concat([df1] * len(df2), ignore_index=True)
    df = pd.concat([df1_repeated, df2],axis=1).reset_index(drop=True)

    return df

# %% [markdown]
# #### XMLTOXLSX

# %%
def load_all_xml(folder_path):
    all_files = glob.glob(os.path.join(folder_path, '**', '*.xml'), recursive=True)
    return all_files

def xml_to_dataframe(folder_path):
    all_files = load_all_xml(folder_path)
    total_files = len(all_files)

    total_df = pd.DataFrame()

    for idx, file_path in enumerate(all_files):
      if idx > 0 and idx % 50 == 0:
        print(f'{idx} 완료 중')
      try:
        temp_df = make_DB(file_path)
        total_df = pd.concat([total_df,temp_df], ignore_index=True)
      except:
        print(f'{file_path}')

    return total_df

# %%
folder_path = '/content/drive/MyDrive/이상행동데이터'
df = xml_to_dataframe(folder_path)

# %%
df.shape
# Out:
# (70351, 24)

# %% [markdown]
# #### 데이터 저장

# %%
final_df = df.drop_duplicates()
final_df = final_df.reset_index(drop=True)
final_df.to_excel(f'{folder_path}/이상행동데이터.xlsx', index=False)
final_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-556018b74533> in <cell line: 1>()
# ----> 1 final_df = df.drop_duplicates()
#       2 final_df = final_df.reset_index(drop=True)
#       3 final_df.to_excel(f'{folder_path}/이상행동데이터.xlsx', index=False)
#       4 final_df
#
# NameError: name 'df' is not defined

# %% [markdown]
# ----------------------------------

# %% [markdown]
# #### 결측값 처리

# %%
final_df = pd.read_excel('/content/drive/MyDrive/이상행동데이터/이상행동데이터_결측포함.xlsx') #파일이름 변경함
final_df.shape
# Out:
# (70339, 24)

# %%
missing_rows = final_df[final_df.isna().any(axis=1)]
missing_rows
# Out:
#           folder                                          filename  width  \
# 30026  datefight  185-6_cam02_datefight01_place02_night_spring.mp4   3840
# 30027  datefight  185-6_cam02_datefight01_place02_night_spring.mp4   3840
# 31482  datefight  194-1_cam03_datefight02_place02_night_summer.mp4   3840
# 31483  datefight  194-1_cam03_datefight02_place02_night_summer.mp4   3840
# 31484  datefight  194-1_cam03_datefight02_place02_night_summer.mp4   3840
# 31485  datefight  194-1_cam03_datefight02_place02_night_summer.mp4   3840
# 31486  datefight  194-1_cam03_datefight02_place02_night_summer.mp4   3840
# 31487  datefight  194-1_cam03_datefight02_place02_night_summer.mp4   3840
# 31488  datefight  194-1_cam03_datefight02_place02_night_summer.mp4   3840
# 33785    robbery      177-5_cam02_robbery01_place01_day_summer.mp4   3840
# 33786    robbery      177-5_cam02_robbery01_place01_day_summer.mp4   3840
# 33803    robbery      177-5_cam01_robbery01_place01_day_spring.mp4   3840
# 34618    robbery    178-6_cam01_robbery02_place02_night_summer.mp4   3840
# 38074   burglary      76-5_cam02_burglary01_place01_day_summer.mp4   3840
# 38860   burglary    66-2_cam01_burglary01_place01_night_summer.mp4   3840
# 39356     wander       122-2_cam01_wander02_place01_day_summer.mp4   3840
# 39357     wander       122-2_cam01_wander02_place01_day_summer.mp4   3840
# 39367     wander       122-2_cam01_wander02_place01_day_spring.mp4   3840
# 39368     wander       122-2_cam01_wander02_place01_day_spring.mp4   3840
# 39393     wander       122-6_cam01_wander02_place01_day_spring.mp4   3840
# 43111  vandalism     85-1_cam02_vandalism01_place04_day_summer.mp4   3840
# 43112  vandalism     85-1_cam02_vandalism01_place04_day_summer.mp4   3840
# 55006      fight       33-3_cam02_fight01_place02_night_spring.mp4   3840
# 55007      fight       33-3_cam02_fight01_place02_night_spring.mp4   3840
# 55008      fight       33-3_cam02_fight01_place02_night_spring.mp4   3840
#
#        height    duration  fps  frames location  season weather  ...  \
# 30026    2160  00:05:08.6   30    9258  PLACE02  SPRING   SUNNY  ...
# 30027    2160  00:05:08.6   30    9258  PLACE02  SPRING   SUNNY  ...
# 31482    2160  00:05:39.0   30   10169  PLACE02  SUMMER   SUNNY  ...
# 31483    2160  00:05:39.0   30   10169  PLACE02  SUMMER   SUNNY  ...
# 31484    2160  00:05:39.0   30   10169  PLACE02  SUMMER   SUNNY  ...
# 31485    2160  00:05:39.0   30   10169  PLACE02  SUMMER   SUNNY  ...
# 31486    2160  00:05:39.0   30   10169  PLACE02  SUMMER   SUNNY  ...
# 31487    2160  00:05:39.0   30   10169  PLACE02  SUMMER   SUNNY  ...
# 31488    2160  00:05:39.0   30   10169  PLACE02  SUMMER   SUNNY  ...
# 33785    2160  00:05:00.3   30    9009  PLACE01  SUMMER   SUNNY  ...
# 33786    2160  00:05:00.3   30    9009  PLACE01  SUMMER   SUNNY  ...
# 33803    2160  00:05:06.3   30    9189  PLACE01  SPRING   SUNNY  ...
# 34618    2160  00:05:10.2   30    9307  PLACE02  SUMMER   SUNNY  ...
# 38074    2160  00:04:43.4   30    8500  PLACE01  SUMMER   SUNNY  ...
# 38860    2160  00:04:56.4   30    8890  PLACE01  SUMMER   SUNNY  ...
# 39356    2160  00:05:18.0   30    9538  PLACE01  SUMMER   SUNNY  ...
# 39357    2160  00:05:18.0   30    9538  PLACE01  SUMMER   SUNNY  ...
# 39367    2160  00:08:26.0   30   15180  PLACE01  SPRING   SUNNY  ...
# 39368    2160  00:08:26.0   30   15180  PLACE01  SPRING   SUNNY  ...
# 39393    2160  00:05:26.1   30    9781  PLACE01  SPRING   SUNNY  ...
# 43111    2160  00:05:13.3   30    9399  PLACE04  SUMMER   SUNNY  ...
# 43112    2160  00:05:13.3   30    9399  PLACE04  SUMMER   SUNNY  ...
# 55006    2160  00:04:59.1   30    8973  PLACE01  SPRING   SUNNY  ...
# 55007    2160  00:04:59.1   30    8973  PLACE01  SPRING   SUNNY  ...
# 55008    2160  00:04:59.1   30    8973  PLACE01  SPRING   SUNNY  ...
#
#       action_duration                                    file_objectname  \
# 30026      00:00:45.4  185-6_cam02_datefight01_place02_night_spring.m...
# 30027      00:00:45.4  185-6_cam02_datefight01_place02_night_spring.m...
# 31482      00:03:09.9  194-1_cam03_datefight02_place02_night_summer.m...
# 31483      00:03:09.9  194-1_cam03_datefight02_place02_night_summer.m...
# 31484      00:03:09.9  194-1_cam03_datefight02_place02_night_summer.m...
# 31485      00:03:09.9  194-1_cam03_datefight02_place02_night_summer.m...
# 31486      00:03:09.9  194-1_cam03_datefight02_place02_night_summer.m...
# 31487      00:03:09.9  194-1_cam03_datefight02_place02_night_summer.m...
# 31488      00:03:09.9  194-1_cam03_datefight02_place02_night_summer.m...
# 33785      00:00:48.1  177-5_cam02_robbery01_place01_day_summer.mp4(p...
# 33786      00:00:48.1  177-5_cam02_robbery01_place01_day_summer.mp4(p...
# 33803      00:01:47.9  177-5_cam01_robbery01_place01_day_spring.mp4(p...
# 34618      00:00:49.7  178-6_cam01_robbery02_place02_night_summer.mp4...
# 38074      00:00:29.1  76-5_cam02_burglary01_place01_day_summer.mp4(p...
# 38860      00:00:36.5  66-2_cam01_burglary01_place01_night_summer.mp4...
# 39356      00:04:21.2  122-2_cam01_wander02_place01_day_summer.mp4(pe...
# 39357      00:04:21.2  122-2_cam01_wander02_place01_day_summer.mp4(pe...
# 39367      00:04:34.0  122-2_cam01_wander02_place01_day_spring.mp4(pe...
# 39368      00:04:34.0  122-2_cam01_wander02_place01_day_spring.mp4(pe...
# 39393      00:00:59.0  122-6_cam01_wander02_place01_day_spring.mp4(pe...
# 43111      00:02:00.0  85-1_cam02_vandalism01_place04_day_summer.mp4(...
# 43112      00:02:00.0  85-1_cam02_vandalism01_place04_day_summer.mp4(...
# 55006      00:01:45.5  33-3_cam02_fight01_place02_night_spring.mp4(pe...
# 55007      00:01:45.5  33-3_cam02_fight01_place02_night_spring.mp4(pe...
# 55008      00:01:45.5  33-3_cam02_fight01_place02_night_spring.mp4(pe...
#
#       character objectname keyframe keypoint_x keypoint_y actionname  \
# 30026       NaN   person_2     7986       2310       1204   falldown
# 30027       NaN   person_2     7986       2310       1204   falldown
# 31482       NaN   person_2     7302       1713        877   touching
# 31483       NaN   person_2     7302       1713        877   touching
# 31484       NaN   person_2     7302       1713        877   touching
# 31485       NaN   person_2     7302       1713        877   touching
# 31486       NaN   person_2     7302       1713        877   touching
# 31487       NaN   person_2     7302       1713        877   touching
# 31488       NaN   person_2     7302       1713        877   touching
# 33785       NaN   person_2     7522       2720       1393   falldown
# 33786       NaN   person_2     7522       2720       1393   falldown
# 33803       NaN   person_2     6420       1051        487   falldown
# 34618       NaN   person_2     7146       2876        862    pushing
# 38074       M50   person_1     6644       1560        971        NaN
# 38860       F60   person_1     6521       2442        819        NaN
# 39356       M20   person_1     1704       2128        764        NaN
# 39357       M20   person_1     1704       2128        764        NaN
# 39367       M20   person_1     3648       2283        742        NaN
# 39368       M20   person_1     3648       2283        742        NaN
# 39393       M20   person_1     4092       1925        846        NaN
# 43111       M10   person_1     5070       1148        417        NaN
# 43112       M10   person_1     5070       1148        417        NaN
# 55006       NaN   person_4     6792        454        553    kicking
# 55007       NaN   person_4     6792        454        553   punching
# 55008       NaN   person_4     6792        454        553   falldown
#
#        actionframe_start  actionframe_end
# 30026               7986             8064
# 30027               8321             8365
# 31482               7302             7373
# 31483               7457             7611
# 31484               7994             8135
# 31485               8346             8441
# 31486               8823             9045
# 31487               9133             9219
# 31488               9462             9904
# 33785               7522             7706
# 33786               7979             8127
# 33803               6420             6552
# 34618               7146             7191
# 38074               6644             7008
# 38860               6521             7042
# 39356               2594             2889
# 39357               3797             4036
# 39367               7263             7497
# 39368               8788             8940
# 39393               5581             5857
# 43111               5134             5186
# 43112               8455             8495
# 55006               6792             6835
# 55007               6910             6947
# 55008               8059             8148
#
# [25 rows x 24 columns]

# %% [markdown]
# ##### 1. character 결측 처리

# %%
# 표기오류로 인한 결측 처리
final_df[final_df['filename'] == '185-6_cam02_datefight01_place02_night_spring.mp4']

final_df.loc[30026,'character'] = 'F40'
final_df.loc[30027,'character'] = 'F40'

# %%
select_df1 = final_df[final_df['file_objectname'] == '194-1_cam03_datefight02_place02_night_summer.mp4(person_1)']
select_df2 = final_df[final_df['file_objectname'] == '194-1_cam03_datefight02_place02_night_summer.mp4(person_2)']

final_df.loc[select_df1.index, 'character'] = 'F20'
final_df.loc[select_df2.index, 'character'] = 'M20'

# 해당 데이터 population 변경
select_df = final_df[final_df['filename'] == '194-1_cam03_datefight02_place02_night_summer.mp4']
final_df.loc[select_df.index, 'population'] = 2

# %%
select_df = final_df[final_df['file_objectname'] == '177-5_cam02_robbery01_place01_day_summer.mp4(person_2)']
final_df.loc[select_df.index, 'character'] = 'F20'

# 해당 데이터 population 변경
select_df = final_df[final_df['filename'] == '177-5_cam02_robbery01_place01_day_summer.mp4']
final_df.loc[select_df.index, 'population'] = 2

# %%
select_df = final_df[final_df['file_objectname'] == '177-5_cam01_robbery01_place01_day_spring.mp4(person_2)']
final_df.loc[select_df.index, 'character'] = 'F20'

# 해당 데이터 population 변경
select_df = final_df[final_df['filename'] == '177-5_cam01_robbery01_place01_day_spring.mp4']
final_df.loc[select_df.index, 'population'] = 2

# %%
select_df = final_df[final_df['file_objectname'] == '178-6_cam01_robbery02_place02_night_summer.mp4(person_2)']
final_df.loc[select_df.index, 'character'] = 'M30'

# 해당 데이터 population 변경
select_df = final_df[final_df['filename'] == '178-6_cam01_robbery02_place02_night_summer.mp4']
final_df.loc[select_df.index, 'population'] = 3

# %%
select_df = final_df[final_df['file_objectname'] == '33-3_cam02_fight01_place02_night_spring.mp4(person_4)']
final_df.loc[select_df.index, 'character'] = 'M30'

# 해당 데이터 population 변경
select_df = final_df[final_df['filename'] == '194-1_cam03_datefight02_place02_night_summer.mp4']
final_df.loc[select_df.index, 'population'] = 4

# %% [markdown]
# ##### 2. actionname 결측 처리

# %%
select_df = final_df[(final_df['filename'] == '76-5_cam02_burglary01_place01_day_summer.mp4') & (final_df['actionname'].isna())]

final_df.loc[select_df.index, 'actionname'] = 'pick up'

# %%
select_df = final_df[(final_df['filename'] == '66-2_cam01_burglary01_place01_night_summer.mp4') & (final_df['actionname'].isna())]

final_df.loc[select_df.index, 'actionname'] = 'pick up'

# %%
select_df = final_df[(final_df['filename'] == '122-2_cam01_wander02_place01_day_summer.mp4') & (final_df['actionname'].isna())]

final_df.loc[select_df.index, 'actionname'] = 'stop and go'

# %%
select_df = final_df[(final_df['filename'] == '122-2_cam01_wander02_place01_day_spring.mp4') & (final_df['actionname'].isna())]

final_df.loc[select_df.index, 'actionname'] = 'stop and go'

# %%
select_df = final_df[(final_df['filename'] == '122-6_cam01_wander02_place01_day_spring.mp4') & (final_df['actionname'].isna())]

final_df.loc[select_df.index, 'actionname'] = 'stop and go'

# %%
select_df = final_df[(final_df['filename'] == '85-1_cam02_vandalism01_place04_day_summer.mp4') & (final_df['actionname'].isna())]

final_df.loc[select_df.index, 'actionname'] = 'pushing'

# %% [markdown]
# ##### 3. 결측값 확인

# %%
missing_rows = final_df[final_df.isna().any(axis=1)]
missing_rows
# Out:
# Empty DataFrame
# Columns: [folder, filename, width, height, duration, fps, frames, location, season, weather, time, population, eventname, starttime, action_duration, file_objectname, character, objectname, keyframe, keypoint_x, keypoint_y, actionname, actionframe_start, actionframe_end]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# -----------------------------------

# %% [markdown]
# #### 오류수정

# %%
# 행동정보 오류 수정

final_df.loc[final_df['eventname'] != final_df['folder'], 'folder'] = 'assault'

# %% [markdown]
# #### 데이터 저장

# %%
final_df.to_excel('/content/drive/MyDrive/이상행동데이터/이상행동데이터.xlsx', index=False)
final_df
# Out:
#         folder                                       filename  width  height  \
# 0      assault  10-1_cam01_assault03_place07_night_spring.mp4   3840    2160
# 1      assault  10-1_cam01_assault03_place07_night_spring.mp4   3840    2160
# 2      assault  10-1_cam01_assault03_place07_night_spring.mp4   3840    2160
# 3      assault  10-1_cam01_assault03_place07_night_spring.mp4   3840    2160
# 4      assault  10-1_cam01_assault03_place07_night_spring.mp4   3840    2160
# ...        ...                                            ...    ...     ...
# 70334    swoon     118-6_cam02_swoon02_place10_day_summer.mp4   3840    2160
# 70335    swoon     118-6_cam01_swoon02_place10_day_spring.mp4   3840    2160
# 70336    swoon     118-6_cam01_swoon02_place10_day_spring.mp4   3840    2160
# 70337    swoon     118-6_cam01_swoon02_place10_day_summer.mp4   3840    2160
# 70338    swoon     118-6_cam01_swoon02_place10_day_summer.mp4   3840    2160
#
#          duration  fps  frames location  season weather  ... action_duration  \
# 0      00:05:08.2   30    9245  PLACE07  SPRING   SUNNY  ...      00:02:20.2
# 1      00:05:08.2   30    9245  PLACE07  SPRING   SUNNY  ...      00:02:20.2
# 2      00:05:08.2   30    9245  PLACE07  SPRING   SUNNY  ...      00:02:20.2
# 3      00:05:08.2   30    9245  PLACE07  SPRING   SUNNY  ...      00:02:20.2
# 4      00:05:08.2   30    9245  PLACE07  SPRING   SUNNY  ...      00:02:20.2
# ...           ...  ...     ...      ...     ...     ...  ...             ...
# 70334  00:05:00.3   30    9009  PLACE10  SUMMER   SUNNY  ...      00:00:04.2
# 70335  00:05:00.3   30    9009  PLACE10  SPRING   SUNNY  ...      00:00:12.7
# 70336  00:05:00.3   30    9009  PLACE10  SPRING   SUNNY  ...      00:00:12.7
# 70337  00:05:00.3   30    9009  PLACE10  SUMMER   SUNNY  ...      00:00:12.9
# 70338  00:05:00.3   30    9009  PLACE10  SUMMER   SUNNY  ...      00:00:12.9
#
#                                          file_objectname character objectname  \
# 0      10-1_cam01_assault03_place07_night_spring.mp4(...       F20   person_1
# 1      10-1_cam01_assault03_place07_night_spring.mp4(...       F20   person_1
# 2      10-1_cam01_assault03_place07_night_spring.mp4(...       F20   person_1
# 3      10-1_cam01_assault03_place07_night_spring.mp4(...       F20   person_1
# 4      10-1_cam01_assault03_place07_night_spring.mp4(...       F20   person_1
# ...                                                  ...       ...        ...
# 70334  118-6_cam02_swoon02_place10_day_summer.mp4(per...       F30   person_1
# 70335  118-6_cam01_swoon02_place10_day_spring.mp4(per...       F30   person_1
# 70336  118-6_cam01_swoon02_place10_day_spring.mp4(per...       F30   person_1
# 70337  118-6_cam01_swoon02_place10_day_summer.mp4(per...       F30   person_1
# 70338  118-6_cam01_swoon02_place10_day_summer.mp4(per...       F30   person_1
#
#       keyframe keypoint_x keypoint_y actionname  actionframe_start  \
# 0         4382       2528        654    pushing               4382
# 1         4382       2528        654    pushing               4483
# 2         4382       2528        654    pushing               4546
# 3         4382       2528        654    pushing               4727
# 4         4382       2528        654    pushing               4792
# ...        ...        ...        ...        ...                ...
# 70334     8883       1202       1159   falldown               8943
# 70335     7976       2403        650   falldown               8602
# 70336     7976       2403        650   falldown               8672
# 70337     8149       2424        743   falldown               8622
# 70338     8149       2424        743   falldown               8760
#
#        actionframe_end
# 0                 4418
# 1                 4506
# 2                 4592
# 3                 4753
# 4                 4820
# ...                ...
# 70334             9009
# 70335             8672
# 70336             9009
# 70337             8760
# 70338             9009
#
# [70339 rows x 24 columns]

# %% [markdown]
# #### 데이터 확인

# %%
final_df['actionname'].value_counts()
# Out:
# actionname
# punching       11141
# pulling         9611
# kicking         9193
# pushing         9189
# falldown        6417
# threaten        6326
# totter          5314
# sitdown         4266
# stop and go     2976
# carring         1346
# throwing         986
# drop             683
# pick up          629
# touching         625
# hugging          594
# around           379
# stealing         275
# walking          159
# climbwall        127
# piercing          74
# running           28
# standing           1
# Name: count, dtype: int64

# %%
final_df['folder'].value_counts()
# Out:
# folder
# fight        22721
# assault      16218
# drunken       8948
# datefight     7068
# wander        3356
# vandalism     2613
# swoon         2582
# robbery       2129
# burglary      1920
# dump          1091
# kidnap        1072
# trespass       621
# Name: count, dtype: int64

# %%
folder_counts = final_df.groupby('folder')['actionname'].value_counts()
fight_counts = folder_counts.loc[folder_counts.index.get_level_values(0) == 'trespass']
fight_counts
# Out:
# folder    actionname
# trespass  pulling       338
#           walking       155
#           climbwall     127
#           running         1
# Name: count, dtype: int64

# %% [markdown]
# #### 데이터 분할 생성

# %%
for i in final_df['folder'].unique():
  print(i)
# Out:
# assault
# drunken
# kidnap
# datefight
# robbery
# dump
# trespass
# burglary
# wander
# vandalism
# fight
# swoon

# %%
folder_path = '/content/drive/MyDrive/이상행동데이터'
for i in final_df['folder'].unique():
  select_df = final_df[final_df['folder'] == i]
  select_df.to_excel(f'{folder_path}/{i}.xlsx', index=False)
